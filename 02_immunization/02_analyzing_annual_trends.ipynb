# %%
import pandas as pd

# %%
annual_df = pd.read_csv('outputs/annual_immunization.csv')

prov_df = annual_df[annual_df.Geography == 'Province']

prov_df.groupby('Income_Class')['FIC_Percent'].describe()
# Out:
#               count       mean        std        min        25%        50%  \
# Income_Class
# 1st           528.0  63.773052  14.162744   0.636494  56.087264  64.045636
# 2nd            96.0  65.929722  11.516969  39.156250  58.812298  65.528691
# 3rd            16.0  61.463458  11.575484  45.084409  53.868710  59.248679
# 4th            16.0  58.891154  27.176133   0.636494  46.803882  63.672573
#
#                     75%         max
# Income_Class
# 1st           72.002301  108.002455
# 2nd           72.833794   92.116093
# 3rd           67.320447   86.670800
# 4th           75.959057   94.881890

# %%
prov_df.boxplot(by='Income_Class', column='CPAB_Percent')
# Out:
# <Axes: title={'center': 'CPAB_Percent'}, xlabel='Income_Class'>

# %%
prov_df.FIC_Percent.hist()
# Out:
# <Axes: >
